# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")

# %matplotlib inline

# %% [markdown]
# # Flight:

# %% [markdown]
# `Question 1`.  Load the flight price dataset and examine its dimensions. How many rows and columns does the dataset have?
#
# `Answer` :

# %%
df =pd.read_excel('flight_price.xlsx')
print(f"There are {df.shape[0]} rows and {df.shape[1]} columns")
# Out:
# There are 10683 rows and 11 columns

# %% [markdown]
# `Question 2`. What is the distribution of flight prices in the dataset? Create a histogram to visualize the distribution.
#
# `Answer` :

# %%
plt.figure(figsize=(10, 6))
df.hist(column= 'Price', bins=30, grid=False)
plt.show()

# %% [markdown]
# `Question 3`. What is the range of prices in the dataset? What is the minimum and maximum price?
#
# `Answer` :

# %%
maximum = df['Price'].max()
minimum = df['Price'].min()
print(f"The range of prices in the dataset belongs from {minimum} to {maximum}.")
# Out:
# The range of prices in the dataset belongs from 1759 to 79512.

# %%
df.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination                  Route  \
# 0     IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1  Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662

# %% [markdown]
# `Question 4`. How does the price of flights vary by airline? Create a boxplot to compare the prices of different
# airlines.
#
# `Answer` :

# %%
plt.figure(figsize=(15, 6))
sns.boxplot(data= df, x='Price', y='Airline' )
# Out:
# <AxesSubplot: xlabel='Price', ylabel='Airline'>

# %% [markdown]
# `Question 5`. Are there any outliers in the dataset? Identify any potential outliers using a boxplot and describe how
# they may impact your analysis.
#
# `Answer` :
# Impact on Analysis:
# -    Skewing Descriptive Statistics: Outliers can heavily influence summary statistics like the mean and standard deviation. The mean can be skewed by extreme values, making it an unreliable measure of central tendency. Similarly, the standard deviation might be significantly affected, misleading the assessment of data variability.
#
# -    Altering Data Distribution Perception: Outliers might give the impression of a different distribution in the data than what it actually represents. For instance, a dataset might seem normally distributed, but outliers can distort this perception.
#
# -    Affecting Relationships in Analysis: In analyses involving regression or correlation, outliers can significantly impact the relationships observed. They might strongly influence the results, potentially misleading the interpretation of correlations or regression coefficients.
#
# -    Statistical Assumptions: Outliers can violate assumptions of some statistical methods. For example, parametric statistical tests might assume normality and homogeneity of variance, which outliers can disrupt, leading to inaccurate results.

# %%
###Yes in Price column
sns.boxplot(data= df, y='Price')
# Out:
# <AxesSubplot: ylabel='Price'>

# %% [markdown]
# `Question 6`. You are working for a travel agency, and your boss has asked you to analyze the Flight Price dataset to identify the peak travel season. What features would you analyze to identify the peak season, and how would you present your findings to your boss?
#
# `Answer` :
# 1. Date and Time Related Features:
# -    Month, Season, and Day of the Week: Analyzing the distribution of flight prices over months and seasons can reveal patterns. The day of the week can also impact prices.
# -    Holidays and Special Events: Check for price fluctuations around holidays or significant events impacting travel demand.
#
# 2. How to Present Findings to Your Boss:
# -    Visualizations: Use line plots, bar graphs, or box plots to illustrate the fluctuations in prices over time. Visual representations are powerful tools to showcase trends.
#
# -    Highlight Key Findings: Emphasize the identified peak seasons and the factors influencing these peaks. Provide insights into why these times might be more expensive or popular for travel.

# %% [markdown]
# `Question 7`. You are a data analyst for a flight booking website, and you have been asked to analyze the Flight Price dataset to identify any trends in flight prices. What features would you analyze to identify these trends, and what visualizations would you use to present your findings to your team?
#
# `Answer` :
# 1. Date and Time Related Features:
# -    Month, Season, and Day of the Week: Analyzing the distribution of flight prices over months and seasons can reveal patterns. The day of the week can also impact prices.
# -    Holidays and Special Events: Check for price fluctuations around holidays or significant events impacting travel demand.
#
# 2. Weather and Seasonality:
# -    Weather Conditions: Depending on the destination, weather can impact travel demand and, subsequently, prices.
# 3.    Flight Route and Destination:
# -    Popular Routes: Explore the busiest routes and their price variations.
# -    Destination Demand: Analyze prices for specific destinations during different times of the year.
#
# 4. How to Present Findings to Team:
# -    Visualizations: Use line plots, bar graphs, or box plots to illustrate the fluctuations in prices over time. Visual representations are powerful tools to showcase trends.
#
# -    Highlight Key Findings: Emphasize the identified peak seasons and the factors influencing these peaks. Provide insights into why these times might be more expensive or popular for travel.
#
# -    Comparison and Analysis: Show comparative analyses between different months, seasons, or years to make patterns and peaks more evident.
#
# -    Recommendations: Based on your analysis, provide recommendations on strategies the agency can adopt to leverage peak seasons. For instance, marketing campaigns, targeted offers, or inventory management during these periods.
#
# -   Insights for Decision Making: Ensure to present actionable insights that can guide the agency's decisions and help in planning marketing strategies or adjusting prices.

# %% [markdown]
# `Question 8`. You are a data scientist working for an airline company, and you have been asked to analyze the Flight Price dataset to identify the factors that affect flight prices. What features would you analyze to identify these factors, and how would you present your findings to the management team?
#
# `Answer` :
# 1. Date and Time Related Features:
# -    Month, Season, and Day of the Week: Analyzing the distribution of flight prices over months and seasons can reveal patterns. The day of the week can also impact prices.
# -    Holidays and Special Events: Check for price fluctuations around holidays or significant events impacting travel demand.
# 2. Flight Route and Destination:
# -    Popular Routes: Explore the busiest routes and their price variations.
# -    Destination Demand: Analyze prices for specific destinations during different times of the year.
# 3. Historical Price Trends:
# -    Year-over-Year Comparison: Compare prices across multiple years to identify consistent peak seasons.
# -    Trend Analysis: Look for upward or downward trends in prices during specific periods.
#  4. Booking Lead Time:
# -    Lead Time vs. Price: Analyze if the lead time affects flight prices during peak seasons.
# 5. Weather and Seasonality:
# -    Weather Conditions: Depending on the destination, weather can impact travel demand and, subsequently, prices.
#
# 6. Visualizations: Use line plots, bar graphs, or box plots to illustrate the fluctuations in prices over time. Visual representations are powerful tools to showcase trends.

# %% [markdown]
# # Google Playstore:

# %%
df=pd.read_csv('https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv')
df.head(5)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %% [markdown]
# `Question 9`:Load the Google Playstore dataset and examine its dimensions. How many rows and columns does the dataset have?
#
# `Answer` :

# %%
print(f"There are {df.shape[0]} rows and {df.shape[1]} columns")
# Out:
# There are 10841 rows and 13 columns

# %% [markdown]
# `Question 10`:How does the rating of apps vary by category? Create a boxplot to compare the ratings of different app categories.
#
# `Answer` :

# %%
plt.figure(figsize=(10, 8))
sns.boxplot(data= df, x='Rating', y='Category' )
plt.tight_layout()

# %% [markdown]
# `Question 11`:Are there any missing values in the dataset? Identify any missing values and describe how they may
# impact your analysis.

# %%
df.isna().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %% [markdown]
# `Answer` : In Columns  Rating, Type , Current Ver, Android Ver having missing values.
# 1. Biased Analysis:
# -    Underestimation or Overestimation: Missing values can skew statistical measures, such as means, medians, and variances, leading to underestimation or overestimation of parameters, affecting the overall analysis.
# 2. Data Quality and Representation:
# -    Reduced Sample Size: Missing data reduces the sample size, potentially affecting the representativeness of the dataset and leading to less reliable analyses.
# 3. Analytical Techniques and Models:
# -    Model Performance: Missing data might impact the performance of predictive models or statistical techniques, leading to biased results or incorrect inferences.
# 4. Interpretation of Relationships:
# -    Correlations and Relationships: Missing values can impact the analysis of relationships between variables, affecting the interpretation of correlations and causations.
# 5. Decision Making and Inferences:
# -    Inaccurate Decision-Making: Incomplete data might lead to incorrect inferences, impacting the decision-making process based on flawed or incomplete information.

# %% [markdown]
# `Question 12`:What is the relationship between the size of an app and its rating? Create a scatter plot to visualize the relationship.
#
# `Answer` :

# %%
df['Size']=df['Size'].str.replace('M','000')
df['Size']=df['Size'].str.replace('k','')
df['Size']=df['Size'].replace('Varies with device',np.nan)
df['Size']=df['Size'].replace('1,000+','1.000')
df['Size']=df['Size'].astype(float)

# %%
df= df[df["Rating"] != 19.0]

# %%
# the apps which size btw 20 to 40 mb get more user ratings
sns.scatterplot(data=df, y='Size', x='Rating')
plt.tight_layout()

# %% [markdown]
# `Question 13`:How does the type of app affect its price? Create a bar chart to compare average prices by app type.
#
# `Answer` :
# ### Observation
# - Developing a Finace, Lifestyle, medical app have highest prices in comparision to others.

# %%
df['Price'] = df['Price'].str.extract('(\d+)')
df['Price'] = df['Price'].astype(float)

# %%
average_prices = df.groupby('Category')['Price'].mean().reset_index()

# Plotting the bar chart
plt.figure(figsize=(10, 6))

plt.bar(average_prices['Category'],  average_prices['Price'], color='skyblue')
plt.xlabel('App Type')
plt.ylabel('Average Price')
plt.title('Average Prices by App Type')

# Rotate x-labels for better readability (if needed)
plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %%
# Group by 'Category' and sum the 'Prices' for each app
Price_stats = df.groupby('Category')['Price'].mean()

# To visualize the top 10 most Priced apps:
top_10_Price = Price_stats.nlargest(10)

print(top_10_Price)
# Out:
# Category
# FINANCE                7.879781
# LIFESTYLE              6.138743
# MEDICAL                2.900648
# EVENTS                 1.703125
# FAMILY                 1.146552
# PRODUCTIVITY           0.535377
# BOOKS_AND_REFERENCE    0.424242
# BUSINESS               0.373913
# PHOTOGRAPHY            0.343284
# WEATHER                0.304878
# Name: Price, dtype: float64

# %%
plt.figure(figsize=(8, 6))
top_10_Price.plot(kind='bar', color='skyblue')
plt.xlabel('Category')
plt.ylabel('Price')
plt.title('Top 10 Installed Apps')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# `Question 14`:What are the top 10 most popular apps in the dataset? Create a frequency table to identify the apps with the highest number of installs.
#
# `Answer` :

# %%
df['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0'], dtype=object)

# %%
replace = ['+',',','$']
for x in  replace:
    df['Installs'] = df['Installs'].str.replace(x,'')
    
df = df[df['Installs'] !='Free']

df['Installs'] = df['Installs'].astype(int)

df['Installs'].unique()
# Out:
# array([     10000,     500000,    5000000,   50000000,     100000,
#             50000,    1000000,   10000000,       5000,  100000000,
#        1000000000,       1000,  500000000,         50,        100,
#               500,         10,          1,          5,          0])

# %%
# Group by 'App Name' and sum the 'No. of Installs' for each app
install_stats = df.groupby('App')['Installs'].sum()

# To visualize the top 10 most installed apps:
top_10_installed = install_stats.nlargest(10)

print(top_10_installed)
# Out:
# App
# Subway Surfers                  6000000000
# Google Drive                    4000000000
# Google News                     4000000000
# Google Photos                   4000000000
# Hangouts                        4000000000
# Instagram                       4000000000
# Candy Crush Saga                3500000000
# Gmail                           3000000000
# Google Chrome: Fast & Secure    3000000000
# Maps - Navigate & Explore       3000000000
# Name: Installs, dtype: int64

# %%
plt.figure(figsize=(8, 6))
top_10_installed.plot(kind='bar', color='skyblue')
plt.xlabel('App Name')
plt.ylabel('Total Installs')
plt.title('Top 10 Installed Apps')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# `Question 15`:A company wants to launch a new app on the Google Playstore and has asked you to analyze the Google Playstore dataset to identify the most popular app categories. How would you approach this task, and what features would you analyze to make recommendations to the company?
#
# `Answer` :

# %%
df['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION'],
#       dtype=object)

# %% [markdown]
# ## Obsevation
# There are two category Game and Communication which have highest no. of installs as well as revies.

# %%
category_stats = df.groupby('Category')[['Installs', 'Reviews']].sum()

# Finding the top 10 categories with the highest installs and reviews
top_10_category = category_stats.nlargest(10, 'Installs')  # Assuming 'Installs' is the key metric
print(top_10_category)
# Out:
#                        Installs
# Category
# GAME                35086024415
# COMMUNICATION       32647276251
# PRODUCTIVITY        14176091369
# SOCIAL              14069867902
# TOOLS               11452771915
# FAMILY              10258263505
# PHOTOGRAPHY         10088247655
# NEWS_AND_MAGAZINES   7496317760
# TRAVEL_AND_LOCAL     6868887146
# VIDEO_PLAYERS        6222002720

# %%
plt.figure(figsize=(8, 6))
top_10_category.plot(kind='bar', color='skyblue')
plt.xlabel('Category')
plt.ylabel('Total Installs')
plt.title('Top 10 category Apps')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# `Question 16`:A mobile app development company wants to analyze the Google Playstore dataset to identify the most successful app developers. What features would you analyze to make recommendations to the company, and what data visualizations would you use to present your findings?
#
# `Answer` :
# ## Identifying the Most Successful App Developers in Google Playstore Dataset
#
# ### Features for Analysis:
#
# 1. **Number of Installs**: Assess the popularity of apps developed by each company based on total installs.
# 2. **Ratings and Reviews**: Understand user satisfaction and engagement via average ratings and total reviews per developer.
# 3. **App Count per Developer**: Evaluate the volume of apps published by each developer.
# 4. **Category Distribution**: Analyze the diversity of app categories developed by each company.
#
# ### Methodologies:
#
# 1. **Grouping by Developer**:
#    - Aggregate data by developer to summarize installs, ratings, reviews, and app count.
#
# 2. **Ranking and Comparison**:
#    - Rank developers based on metrics to identify top performers.
#
# ### Visualizations for Presentation:
#
# 1. **Bar Charts or Pie Charts**:
#    - Display top developers based on total installs, average ratings, or total reviews using bar or pie charts.
#
# 2. **Scatter Plots**:
#    - Plot relationships between app count and installs/ratings to identify correlations.
#
# 3. **Stacked Bar Charts**:
#    - Compare category distribution of apps developed by each company using stacked bar charts.
#
# ### Insights for Recommendations:
#
# - **Top Performers**: Highlight developers with the highest installs, best ratings, and most engagement.
# - **Trends and Patterns**: Identify successful app categories or specific strategies for top developers.
# - **Competitor Analysis**: Compare successful developers and analyze their success factors.

# %% [markdown]
# `Question 17`:A marketing research firm wants to analyze the Google Playstore dataset to identify the best time to
# launch a new app. What features would you analyze to make recommendations to the company, and
# what data visualizations would you use to present your findings?
#
# `Answer` :
# ### Identifying the Optimal Time to Launch a New App - Google Play Store Dataset Analysis
#
# ### Features for Analysis:
#
# 1. **Trend Analysis by Time**:
#    - **Date of Last Update**: Evaluate the frequency of app updates over time to identify trends.
#    - **Seasonal Trends**: Analyze app installations or user engagement patterns over different seasons or months.
#
# 2. **Number of Installs by Time**:
#    - **Installs Trend**: Investigate the number of app installs over time to understand fluctuations.
#
# 3. **Reviews and Ratings Trend**:
#    - **Average Ratings and Reviews**: Assess trends in ratings and reviews over time to gauge user sentiments.
#
# ### Methodologies:
#
# 1. **Temporal Analysis**:
#    - Group the dataset by time periods (months, quarters) and assess changes in installs, updates, ratings, and reviews.
#
# 2. **Seasonal Patterns**:
#    - Analyze patterns in installs, updates, or user engagement across different seasons or specific time frames.
#
# ### Visualizations for Presentation:
#
# 1. **Line Plots**:
#    - Display trends over time for installs, updates, ratings, and reviews using line plots.
#
# 2. **Bar Charts or Box Plots**:
#    - Compare installs, ratings, or reviews across different months or seasons using bar charts or box plots.
#
# 3. **Seasonal Analysis**:
#    - Use heatmaps or line plots to illustrate seasonal variations in app installs, updates, or user engagement.
#
# ### Insights for Recommendations:
#
# - **Peak Times**: Highlight periods with the highest app installs or user engagement based on trends.
# - **Seasonal Variations**: Identify specific months or seasons where app launches might be more successful.
# - **User Sentiments**: Assess any changes in user sentiments or app performance over time.

# %% [markdown]
# ## Complete...
