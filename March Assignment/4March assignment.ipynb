# %% [markdown]
# `Question 1` : Load the "titanic" dataset using the load_dataset function of seaborn. Use Plotly express to plot a
# scatter plot for age and fare columns in the titanic dataset.

# %%
import seaborn as sns
import plotly.express as px

# Load the titanic dataset using seaborn
titanic_df = sns.load_dataset("titanic")

# Plot a scatter plot for age and fare columns using Plotly express
fig = px.scatter(titanic_df, x="age", y="fare")

# Show the plot
fig.show()
# Out:
# <div>                            <div id="4eb3caf5-9821-41db-807e-91d3d78949b2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4eb3caf5-9821-41db-807e-91d3d78949b2")) {                    Plotly.newPlot(                        "4eb3caf5-9821-41db-807e-91d3d78949b2",                        [{"hovertemplate":"age=%{x}<br>fare=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[22.0,38.0,26.0,35.0,35.0,null,54.0,2.0,27.0,14.0,4.0,58.0,20.0,39.0,14.0,55.0,2.0,null,31.0,null,35.0,34.0,15.0,28.0,8.0,38.0,null,19.0,null,null,40.0,null,null,66.0,28.0,42.0,null,21.0,18.0,14.0,40.0,27.0,null,3.0,19.0,null,null,null,null,18.0,7.0,21.0,49.0,29.0,65.0,null,21.0
# ...

# %% [markdown]
# `Question 2` : Using the tips dataset in the Plotly library, plot a box plot using Plotly express.

# %%
import plotly.express as px

# Load the tips dataset from Plotly
tips_df = px.data.tips()

# Create a box plot using Plotly express
fig = px.box(tips_df, x="day", y="total_bill", color="sex")

# Show the plot
fig.show()
# Out:
# <div>                            <div id="ea519dc3-adba-483a-bf7d-9a8c64743043" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ea519dc3-adba-483a-bf7d-9a8c64743043")) {                    Plotly.newPlot(                        "ea519dc3-adba-483a-bf7d-9a8c64743043",                        [{"alignmentgroup":"True","hovertemplate":"sex=Female<br>day=%{x}<br>total_bill=%{y}<extra></extra>","legendgroup":"Female","marker":{"color":"#636efa"},"name":"Female","notched":false,"offsetgroup":"Female","orientation":"v","showlegend":true,"x":["Sun","Sun","Sun","Sun","Sun","Sun","Sat","Sat","Sat","Sat","Sat","Sat","Sun","Sun","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Thur","Thur","Fri","Fri","Fri","Fri","Fri","Sat","Sat","Sat","Sat","Sat","Sun","Sun","Thur",
# ...

# %% [markdown]
# `Question 3` : Using the tips dataset in the Plotly library, Plot a histogram for x= "sex" and y="total_bill" column in
# the tips dataset. Also, use the "smoker" column with the pattern_shape parameter and the "day"
# column with the color parameter.

# %%
import plotly.express as px

# Load the tips dataset from Plotly
tips_df = px.data.tips()

# Create a box plot using Plotly express
fig = px.histogram(tips_df, x="sex", y="total_bill", color="day", pattern_shape='smoker')

# Show the plot
fig.show()
# Out:
# <div>                            <div id="52dd61c3-20fa-433e-80c4-3e5137d4c083" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("52dd61c3-20fa-433e-80c4-3e5137d4c083")) {                    Plotly.newPlot(                        "52dd61c3-20fa-433e-80c4-3e5137d4c083",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"day=Sun<br>smoker=No<br>sex=%{x}<br>sum of total_bill=%{y}<extra></extra>","legendgroup":"Sun, No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Sun, No","offsetgroup":"Sun, No","orientation":"v","showlegend":true,"x":["Female","Male","Male","Male","Female","Male","Male","Male","Male","Male","Male","Female","Male","Male","Female","Male","Female","Male","Female","Male","Male","
# ...

# %% [markdown]
# `Question 4` : Using the iris dataset in the Plotly library, Plot a scatter matrix plot, using the "species" column for
# the color parameter.
# Note: Use "sepal_length", "sepal_width", "petal_length", "petal_width" columns only with the
# dimensions parameter.

# %%
import seaborn as sns
import plotly.express as px

iris=px.data.iris()
fig=px.scatter_matrix(iris,dimensions=["sepal_length", "sepal_width", "petal_length", "petal_width"],color="species")
fig.show()
# Out:
# <div>                            <div id="a9e4a08f-4c2a-4782-bd9e-1efaada361a8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a9e4a08f-4c2a-4782-bd9e-1efaada361a8")) {                    Plotly.newPlot(                        "a9e4a08f-4c2a-4782-bd9e-1efaada361a8",                        [{"dimensions":[{"axis":{"matches":true},"label":"sepal_length","values":[5.1,4.9,4.7,4.6,5.0,5.4,4.6,5.0,4.4,4.9,5.4,4.8,4.8,4.3,5.8,5.7,5.4,5.1,5.7,5.1,5.4,5.1,4.6,5.1,4.8,5.0,5.0,5.2,5.2,4.7,4.8,5.4,5.2,5.5,4.9,5.0,5.5,4.9,4.4,5.1,5.0,4.5,4.4,5.0,5.1,4.8,5.1,4.6,5.3,5.0]},{"axis":{"matches":true},"label":"sepal_width","values":[3.5,3.0,3.2,3.1,3.6,3.9,3.4,3.4,2.9,3.1,3.7,3.4,3.0,3.0,4.0,4.4,3.9,3.5,3.8,3.8,3.4,3.7,3.6,3.3,3.4,3.0,3.4,3.5,3.4,3.2,3.1,3.4,4.1,4.2
# ...

# %% [markdown]
# `Question 5` : What is Distplot? Using Plotly express, plot a distplot.

# %% [markdown]
# Distplot is a function in the Plotly library that creates a histogram and a kernel density estimation (KDE) plot of a single variable in a dataset. The histogram shows the distribution of values in the variable, while the KDE plot shows the estimated probability density function of the variable.

# %%
pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly.figure_factory as ff
import numpy as np
np.random.seed(1)

x = np.random.randn(1000)
hist_data = [x]
group_labels = ['distplot'] # name of the dataset

fig = ff.create_distplot(hist_data, group_labels)
fig.show()
# Out:
# <div>                            <div id="35ef18d0-fe17-4db4-a46a-2dd6d305b48b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("35ef18d0-fe17-4db4-a46a-2dd6d305b48b")) {                    Plotly.newPlot(                        "35ef18d0-fe17-4db4-a46a-2dd6d305b48b",                        [{"autobinx":false,"histnorm":"probability density","legendgroup":"distplot","marker":{"color":"rgb(31, 119, 180)"},"name":"distplot","opacity":0.7,"x":[1.6243453636632417,-0.6117564136500754,-0.5281717522634557,-1.0729686221561705,0.8654076293246785,-2.3015386968802827,1.74481176421648,-0.7612069008951028,0.31903909605709857,-0.2493703754774101,1.462107937044974,-2.060140709497654,-0.3224172040135075,-0.38405435466841564,1.1337694423354374,-1.0998912673140309,-0.
# ...
